# %%
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ## 1. Load the File

# %%
data = np.genfromtxt('/data9/UN3400/data/brf_temp.txt')

# %%
data
# Out:
# array([[ 0.0000000e+00, -1.7270000e+01],
#        [ 4.1670000e-02, -1.7850000e+01],
#        [ 8.3330000e-02, -1.8420000e+01],
#        ...,
#        [ 3.6516597e+02, -1.4530000e+01],
#        [ 3.6520764e+02, -1.4680000e+01],
#        [ 3.6525000e+02, -1.4760000e+01]])

# %% [markdown]
# ## 2a. Numpy Least Squares Method

# %%
N, i = np.shape(data)

# %%
t = data[:,0:1]
t
# Out:
# array([[0.0000000e+00],
#        [4.1670000e-02],
#        [8.3330000e-02],
#        ...,
#        [3.6516597e+02],
#        [3.6520764e+02],
#        [3.6525000e+02]])

# %%
dobs = data[:,1:2]
dobs
# Out:
# array([[-17.27],
#        [-17.85],
#        [-18.42],
#        ...,
#        [-14.53],
#        [-14.68],
#        [-14.76]])

# %%
M = 3
G = np.zeros((N,M))
G[0:N,0:1] = np.ones((N,1))
G[0:N,1:2] = np.cos(((2 * np.pi)/365.25)* t)
G[0:N,2:3] = np.sin(((2 * np.pi)/365.25)* t)
G[0:N,3:4] = 1

# %%
GTG = np.matmul(G.T,G)
GTd = np.matmul(G.T,dobs)
mest = np.linalg.lstsq(GTG,GTd,rcond=None) [0]
mest
# Out:
# array([[  9.04146981],
#        [-11.58329959],
#        [ -4.27083943]])

# %%
dpre = np.matmul(G,mest)
e = dobs - dpre
sigmad2 = np.matmul(e.T,e)/(N-M)
Cd = sigmad2 * np.linalg.inv(GTG)
sm = np.sqrt(np.diag(Cd).reshape(-1,1))
sm
# Out:
# array([[0.05392669],
#        [0.07569392],
#        [0.07681815]])

# %%
print("estimated standard deviation of the data")
print(np.sqrt(sigmad2))
# Out:
# estimated standard deviation of the data
# [[4.99470871]]

# %%
print("estimated solution of model parameters")
for k in range (M):
    print("model parameter %d: %.4f +/- %.4f" % (k, mest[k,0], 2.0*sm[k,0]))
# Out:
# estimated solution of model parameters
# model parameter 0: 9.0415 +/- 0.1079
# model parameter 1: -11.5833 +/- 0.1514
# model parameter 2: -4.2708 +/- 0.1536

# %%
fig,ax = plt.subplots(figsize = (14,4))
plt.axis ([np.min(t), np.max(t), -25,40])
plt.plot(t,dpre, 'k-')
plt.plot(t,dobs, 'tab:purple')
plt.xlabel('Time (Days)')
plt.ylabel('Air Temperature (Celcius)')
plt.title('Daily Air Temperature at Black Rock Forest (Purple) Against A Cubic Prediction (Black)')
# Out:
# Text(0.5, 1.0, 'Daily Air Temperature at Black Rock Forest (Purple) Against A Cubic Prediction (Black)')

# %% [markdown]
# ## 3. Calculate Model Parameters and Standard Error

# %%
P = (2 * np.pi)/365.25

def trigfunc(x, a, b, c):
    y = a * np.cos(P*x) + b*np.sin(P*x) + c
    return y

mest_ez = optimize.curve_fit(trigfunc, xdata = data[:,0], ydata = data[:,1])[0]
a = mest_ez[0]
b = mest_ez[1]
c = mest_ez[2]
dpre_trig = a* np.cos(P*t) + b*np.sin(P*t) + c

# %% [markdown]
# ## 4. Amplitude of D

# %%
D = np.sqrt(a**2 + b**2)
D
# Out:
# 12.34556192685458

# %% [markdown]
# ## 5. Peak

# %%
tmax = max(t)
tmax
# Out:
# array([365.25])

# %% [markdown]
# ## 6. Model Predicted Versus Observed Data

# %%
fig, ax = plt.subplots(nrows = 2, ncols = 1, figsize = (14,10), sharex = True)

ax[0].plot(t, dpre_trig, 'darkblue', label = "Prediction")
ax[0].plot(t, dobs, 'tab:pink', label = "Observed")
ax[0].set_xlabel('Date (Days)')
ax[0].set_ylabel('Temperature (Celcius)')
ax[0].set_title("Daily Air Temperature at Black Rock Forest (Pink) Against A Trigonometric Prediction (Blue)") 
ax[0].margins (x=0)
ax[0].legend(loc = "upper right")

ax[1].margins(x=0)
ax[1].plot(t,e, 'mediumseagreen')
ax[1].set_xlabel('Date (Day)')
ax[1].set_ylabel('Temperature (Celcius)')
ax[1].set_title("Prediction Error For The Daily Air Temperature at Black Rock Forest")
# Out:
# Text(0.5, 1.0, 'Prediction Error For The Daily Air Temperature at Black Rock Forest')
